# %%
import requests
from bs4 import BeautifulSoup

# %%
phn_nm=[]
phn_pr=[]
phn_rt=[]
phn_rew=[]

page_num=input("Enter number of pages")
for i in range(1,int(page_num)+1):
    url="https://www.flipkart.com/search?q=mobile&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+str(i)
    req=requests.get(url)
    content=BeautifulSoup(req.content,'html.parser')
    print(content)
# Out:
# Enter number of pages2
# <!DOCTYPE html>
# ...

# %%
name=content.find_all('div',{"class":"_4rR01T"})
price=content.find_all('div',{"class":"_30jeq3 _1_WHN1"})

rating=content.find_all('div',{"class":"_3LWZlK"})
review=content.find_all('div',{"class":"gUuXy-"})
print("Phone in page "+str(i))
print(len(name))
# Out:
# Phone in page 2
# 24

# %%
for i in name:
    phn_nm.append(i.text)
for i in price:
    phn_pr.append(i.text)
for i in rating:
    phn_rt.append(i.text)
for i in review:
    phn_rew.append(i.text)

# %%
for i in phn_nm:
    print(i)
# Out:
# realme Narzo 30 5G (Racing Blue, 128 GB)
# REDMI 9 Power (Blazing Blue, 64 GB)
# POCO C3 (Arctic Blue, 32 GB)
# Infinix Hot 10 Play (Morandi Green, 64 GB)
# Infinix Hot 10 Play (Aegean Blue, 64 GB)
# REDMI 9 Power (Fiery Red, 64 GB)
# MOTOROLA E7 Power (Coral Red, 64 GB)
# Infinix Smart 5 (Morandi Green, 32 GB)
# Infinix Smart 5 (7° Purple, 32 GB)
# LAVA A3
# POCO X3 Pro (Steel Blue, 128 GB)
# Infinix Hot 10S (Morandi Green, 64 GB)
# realme C11 2021 (Cool Blue, 32 GB)
# Infinix Hot 10S (7° Purple, 64 GB)
# realme C11 2021 (Cool Grey, 32 GB)
# POCO X3 Pro (Graphite Black, 128 GB)
# realme 8 5G (Supersonic Black, 128 GB)
# realme 8 5G (Supersonic Black, 64 GB)
# realme 8 5G (Supersonic Blue, 64 GB)
# realme 8 5G (Supersonic Black, 128 GB)
# POCO M3 Pro 5G (Cool Blue, 128 GB)
# REDMI Note 9 (Shadow Black, 64 GB)
# Nokia TA-1174 / TA-1299
# realme 8 5G (Supersonic Blue, 128 GB)

# %%
for i in phn_pr:
    print(i)
# Out:
# ₹15,999
# ₹10,999
# ₹7,499
# ₹8,999
# ₹8,999
# ₹10,999
# ₹7,999
# ₹7,199
# ₹7,199
# ₹1,073
# ₹18,999
# ₹9,499
# ₹6,999
# ₹9,499
# ₹6,999
# ₹18,999
# ₹14,999
# ₹13,999
# ₹13,999
# ₹16,999
# ₹15,999
# ₹11,499
# ₹1,399
# ₹16,999

# %%
for i in phn_rt:
    print(i)
# Out:
# 4.4
# 4.3
# 4.3
# 4.3
# 4.3
# 4.3
# 4.1
# 4.4
# 4.4
# 4.2
# 4.4
# 4.3
# 4.6
# 4.3
# 4.6
# 4.4
# 4.3
# 4.3
# 4.3
# 4.3
# 4.2
# 4.3
# 4.2
# 4.3
# 4.2
# 5
# 5
# 4.3
# 5
# 1
# 4.3
# 5
# 4
# 4.1
# 5
# 1
# 4.3
# 5
# 1

# %%
for i in phn_rew:
    print(i)
# Out:
# 4.46,905 Ratings & 487 Reviews
# 4.393,589 Ratings & 6,576 Reviews
# 4.32,57,951 Ratings & 18,097 Reviews
# 4.340,170 Ratings & 3,032 Reviews
# 4.340,170 Ratings & 3,032 Reviews
# 4.393,589 Ratings & 6,576 Reviews
# 4.134,555 Ratings & 3,011 Reviews
# 4.430,818 Ratings & 2,295 Reviews
# 4.430,818 Ratings & 2,295 Reviews
# 4.223,859 Ratings & 2,760 Reviews
# 4.433,180 Ratings & 2,995 Reviews
# 4.310,469 Ratings & 885 Reviews
# 4.616 Ratings & 1 Reviews
# 4.310,469 Ratings & 885 Reviews
# 4.616 Ratings & 1 Reviews
# 4.433,180 Ratings & 2,995 Reviews
# 4.326,188 Ratings & 1,987 Reviews
# 4.326,188 Ratings & 1,987 Reviews
# 4.326,188 Ratings & 1,987 Reviews
# 4.320,088 Ratings & 1,652 Reviews
# 4.24,561 Ratings & 370 Reviews
# 4.371,754 Ratings & 5,260 Reviews
# 4.247,757 Ratings & 4,759 Reviews
# 4.320,088 Ratings & 1,652 Reviews

# %%
import pandas as pd

# %%
data={"phone name":phn_nm,"phone price":phn_pr,"phone review":phn_rew}
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#                                     phone name phone price  \
# 0     realme Narzo 30 5G (Racing Blue, 128 GB)     ₹15,999
# 1          REDMI 9 Power (Blazing Blue, 64 GB)     ₹10,999
# 2                 POCO C3 (Arctic Blue, 32 GB)      ₹7,499
# 3   Infinix Hot 10 Play (Morandi Green, 64 GB)      ₹8,999
# 4     Infinix Hot 10 Play (Aegean Blue, 64 GB)      ₹8,999
# 5             REDMI 9 Power (Fiery Red, 64 GB)     ₹10,999
# 6         MOTOROLA E7 Power (Coral Red, 64 GB)      ₹7,999
# 7       Infinix Smart 5 (Morandi Green, 32 GB)      ₹7,199
# 8           Infinix Smart 5 (7° Purple, 32 GB)      ₹7,199
# 9                                      LAVA A3      ₹1,073
# 10            POCO X3 Pro (Steel Blue, 128 GB)     ₹18,999
# 11      Infinix Hot 10S (Morandi Green, 64 GB)      ₹9,499
# 12          realme C11 2021 (Cool Blue, 32 GB)      ₹6,999
# 13          Infinix Hot 10S (7° Purple, 64 GB)      ₹9,499
# 14          realme C11 2021 (Cool Grey, 32 GB)      ₹6,999
# ...
